# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('child_health_16_17.csv')
df.head()
# Out:
#               States Estimated Number of Annual Live Births ##  \
# 0          All India                                27,301,000
# 1      A & N Islands                                     6,000
# 2     Andhra Pradesh                                   880,000
# 3  Arunachal Pradesh                                    28,000
# 4              Assam                                   747,000
#
#   Total Number of reported live births  \
# 0                           15,664,863
# 1                                3,341
# 2                              578,420
# 3                               13,054
# 4                              455,984
#
#    % Live Births to Estimated Annual Live Births  \
# 0                                           57.3
# 1                                           55.6
# 2                                           65.7
# 3                                           46.6
# 4                                           61.0
#
# ...

# %%
df.set_index('States', inplace = True)
df.index.name = None

# %%
df.head()
# Out:
#                   Estimated Number of Annual Live Births ##  \
# All India                                        27,301,000
# A & N Islands                                         6,000
# Andhra Pradesh                                      880,000
# Arunachal Pradesh                                    28,000
# Assam                                               747,000
#
#                   Total Number of reported live births  \
# All India                                   15,664,863
# A & N Islands                                    3,341
# Andhra Pradesh                                 578,420
# Arunachal Pradesh                               13,054
# Assam                                          455,984
#
#                    % Live Births to Estimated Annual Live Births  \
# All India                                                   57.3
# A & N Islands                                               55.6
# Andhra Pradesh                                              65.7
# ...

# %%
df.to_csv('child_health_16_17.csv')

# %%
df = pd.read_csv('child_health_16_17.csv')

# %%
df.head()
# Out:
#                   Estimated Number of Annual Live Births ##  \
# All India                                        27,301,000
# A & N Islands                                         6,000
# Andhra Pradesh                                      880,000
# Arunachal Pradesh                                    28,000
# Assam                                               747,000
#
#                   Total Number of reported live births  \
# All India                                   15,664,863
# A & N Islands                                    3,341
# Andhra Pradesh                                 578,420
# Arunachal Pradesh                               13,054
# Assam                                          455,984
#
#                    % Live Births to Estimated Annual Live Births  \
# All India                                                   57.3
# A & N Islands                                               55.6
# Andhra Pradesh                                              65.7
# ...

# %%
def clean_helper(x):
    df[x] = df[x].apply(lambda x : x.replace(',',''))
    df[x] = df[x].astype(int)

# %%
df.dtypes
# Out:
# Estimated Number of Annual Live Births ##                                                                   object
# Total Number of reported live births                                                                        object
# % Live Births to Estimated Annual Live Births                                                              float64
# % Total Reported Live Births to Total Deliveries                                                           float64
# Total Number of reported Still Births                                                                       object
# % live birth to Reported Birth                                                                             float64
# Number of Infants given OPV 0 (Birth Dose)                                                                  object
# Number of Infants given BCG                                                                                 object
# ...

# %%
clean_helper('Estimated Number of Annual Live Births ##')

# %%
clean_helper('Total Number of reported live births')
# Out:
# ----------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-22-19de973d4cdb> in <module>
# ----> 1 clean_helper('Total Number of reported live births')
#
# <ipython-input-15-4257f4fe0ebf> in clean_helper(x)
#       1 def clean_helper(x):
# ----> 2     df[x] = df[x].apply(lambda x : x.replace(',',''))
#       3     df[x] = df[x].astype(int)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-15-4257f4fe0ebf> in <lambda>(x)
#       1 def clean_helper(x):
# ----> 2     df[x] = df[x].apply(lambda x : x.replace(',',''))
# ...

# %%
l = df.dtypes

# %%
tmp = pd.DataFrame(l)

# %%
l = ['Estimated Number of Annual Live Births ##',
       'Total Number of reported live births',
       'Total Number of reported Still Births',
       'Number of Infants given OPV 0 (Birth Dose)',
       'Number of Infants given BCG', 'Number of Infants given DPT1',
       'Number of Infants given DPT2', 'Number of Infants given DPT3',
       'Number of Infants given Measles',
       'Number of fully immunized children (9-11 months)',
       'Vitamin - A dose 1', 'Adverse Events Following Imunisation (Others)',
       'Total Number of Infant Deaths reported']

# %%
df.drop(columns = ['Unnamed: 17'],inplace = True)

# %%
l = ['Number of Infants given Measles',
 'Number of fully immunized children (9-11 months)',
 'Vitamin - A dose 1',
 'Adverse Events Following Imunisation (Others)',
 'Total Number of Infant Deaths reported']

# %%
for x in l:
    clean_helper(x)

# %%
# Out:
# ----------------------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-64-09616d73ed79> in <module>
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df.dtypes
# Out:
# Estimated Number of Annual Live Births ##                                                                    int64
# Total Number of reported live births                                                                         int64
# % Live Births to Estimated Annual Live Births                                                              float64
# % Total Reported Live Births to Total Deliveries                                                           float64
# Total Number of reported Still Births                                                                        int64
# % live birth to Reported Birth                                                                             float64
# Number of Infants given OPV 0 (Birth Dose)                                                                   int64
# Number of Infants given BCG                                                                                  int64
# ...

# %%
df.loc['A & N Islands',['Number of Infants given Pentavalent 1',
       'Number of Infants given Pentavalent 2',
       'Number of Infants given Pentavalent 3']] = np.nan

# %%
df.head()
# Out:
#                    Estimated Number of Annual Live Births ##  \
# All India                                           27301000
# A & N Islands                                           6000
# Andhra Pradesh                                        880000
# Arunachal Pradesh                                      28000
# Assam                                                 747000
#
#                    Total Number of reported live births  \
# All India                                      15664863
# A & N Islands                                      3341
# Andhra Pradesh                                   578420
# Arunachal Pradesh                                 13054
# Assam                                            455984
#
#                    % Live Births to Estimated Annual Live Births  \
# All India                                                   57.3
# A & N Islands                                               55.6
# ...

# %%
df = pd.read_csv('child_health_15_16.csv')

# %%
df.head()
# Out:
#           Unnamed: 0 Estimated Number of Annual Live Births ##  \
# 0          All India                                26,903,000
# 1      A & N Islands                                     6,000
# 2     Andhra Pradesh                                   873,000
# 3  Arunachal Pradesh                                    28,000
# 4              Assam                                   738,000
#
#   Total Number of reported live births  \
# 0                           15,950,936
# 1                                3,580
# 2                              618,340
# 3                               12,857
# 4                              456,333
#
#    % Live Births to Estimated Annual Live Births  \
# 0                                           59.2
# 1                                           59.6
# 2                                           70.8
# 3                                           45.9
# 4                                           61.8
#
# ...

# %%
df.set_index('Unnamed: 0',inplace = True)
df.head()
# Out:
#                   Estimated Number of Annual Live Births ##  \
# Unnamed: 0
# All India                                        26,903,000
# A & N Islands                                         6,000
# Andhra Pradesh                                      873,000
# Arunachal Pradesh                                    28,000
# Assam                                               738,000
#
#                   Total Number of reported live births  \
# Unnamed: 0
# All India                                   15,950,936
# A & N Islands                                    3,580
# Andhra Pradesh                                 618,340
# Arunachal Pradesh                               12,857
# Assam                                          456,333
#
#                    % Live Births to Estimated Annual Live Births  \
# Unnamed: 0
# All India                                                   59.2
# A & N Islands                                               59.6
# ...

# %%
df.index.name = None

# %%
df.loc['A & N Islands',['Number of Infants given Pentavalent 1',
       'Number of Infants given Pentavalent 2',
       'Number of Infants given Pentavalent 3']] = np.nan

# %%
tmp  = pd.DataFrame(df.dtypes)

# %%
 l = tmp[ tmp[0] == 'object'].index

# %%
for x in  l:
    clean_helper(x)

# %%
l = ['Number of Infants given Pentavalent 1',
       'Number of Infants given Pentavalent 2',
       'Number of Infants given Pentavalent 3']

# %%
for x in l:
    df[x] = df[x].astype(int)

# %%
df[l]
# Out:
#                       Number of Infants given Pentavalent 1  \
# All India                                        11635042.0
# A & N Islands                                           NaN
# Andhra Pradesh                                     453338.0
# Arunachal Pradesh                                    1464.0
# Assam                                              453145.0
# Bihar                                             1884921.0
# Chandigarh                                           8650.0
# Chhattisgarh                                       375427.0
# Dadra & Nagar Haveli                                 2907.0
# Daman & Diu                                          1577.0
# Delhi                                              217305.0
# Goa                                                 14999.0
# Gujarat                                            875514.0
# Haryana                                            385523.0
# Himachal Pradesh                                    32920.0
# ...

# %%
df.to_csv('child_health_15_16.csv')

# %%
df = pd.read_csv('child_health_14_15.csv')

# %%
df.loc['A & N Islands',l] = '-1'

# %%
tmp = pd.DataFrame(df.dtypes)
l = tmp[tmp[0] == 'object'].index

# %%
df.loc['Lakshadweep','% Children given Vitamin A Dose 9 to Children given Vit A dose1'] = '0'

# %%
tmp = pd.DataFrame(df.dtypes)
l = tmp[tmp[0] == 'object'].index

# %%
l
# Out:
# Index(['Number of Infants given DPT1', 'Number of Infants given DPT2',
#        'Number of Infants given DPT3', 'Number of Infants given Pentavalent 1',
#        'Number of Infants given Pentavalent 2',
#        'Number of Infants given Pentavalent 3',
#        'Number of Infants given Measles',
#        'Number of fully immunized children (9-11 months)',
#        'Vitamin - A dose 1',
#        '% Children given Vitamin A Dose 9 to Children given Vit A dose1',
#        'Adverse Events Following Imunisation (Others)',
#        'Total Number of Infant Deaths reported'],
#       dtype='object')

# %%
df = pd.read_csv('child_health_14_15.csv')

# %%
df.dtypes
# Out:
# Estimated Number of Annual Live Births ##                                                                    int64
# Total Number of reported live births                                                                         int64
# % Live Births to Estimated Annual Live Births                                                              float64
# % Total Reported Live Births to Total Deliveries                                                           float64
# Total Number of reported Still Births                                                                        int64
# % live birth to Reported Birth                                                                             float64
# Number of Newborns weighed at birth                                                                          int64
# Number of Infants given OPV 0 (Birth Dose)                                                                   int64
# ...

# %%
tmp = pd.DataFrame(df.dtypes)

# %%
tmp = pd.DataFrame(df.dtypes)
l = tmp[tmp[0] == 'object'].index

# %%
l
# Out:
# Index(['Number of Infants given Pentavalent 1',
#        'Number of Infants given Pentavalent 2',
#        'Number of Infants given Pentavalent 3'],
#       dtype='object')

# %%
def clean_helper(x):
    df[x] = df[x].apply(lambda x : x.replace(',',''))
    df[x] = df[x].astype(int)

# %%
clean_helper('Total Number of Infant Deaths reported')

# %%
df.dtypes
# Out:
# Estimated Number of Annual Live Births ##                                                                    int64
# Total Number of reported live births                                                                         int64
# % Live Births to Estimated Annual Live Births                                                              float64
# % Total Reported Live Births to Total Deliveries                                                           float64
# Total Number of reported Still Births                                                                        int64
# % live birth to Reported Birth                                                                             float64
# Number of Newborns weighed at birth                                                                          int64
# Number of Infants given OPV 0 (Birth Dose)                                                                   int64
# ...

# %%
df[l]
# Out:
#                      Number of Infants given DPT1  \
# All India                              13,639,560
# A & N Islands                               4,001
# Andhra Pradesh                            604,480
# Arunachal Pradesh                          15,864
# Assam                                     463,419
# Bihar                                   1,914,131
# Chandigarh                                 11,745
# Chhattisgarh                              406,336
# Dadra & Nagar Haveli                        5,166
# Daman & Diu                                 2,579
# Delhi                                      29,364
# Goa                                           308
# Gujarat                                    25,186
# Haryana                                     1,545
# Himachal Pradesh                           80,011
# Jammu & Kashmir                             4,733
# Jharkhand                                 552,051
# Karnataka                                  14,273
# ...

# %%
l = [
       'Number of Infants given Measles','Vitamin - A dose 1',
       '% Children given Vitamin A Dose 9 to Children given Vit A dose1',
       'Adverse Events Following Imunisation (Others)',
       'Total Number of Infant Deaths reported']

# %%
df[l]
# Out:
#                       Number of Infants given Measles  Vitamin - A dose 1  \
# All India                                    17052409            14930230
# A & N Islands                                    3781                3692
# Andhra Pradesh                                 599742              587508
# Arunachal Pradesh                               13683                4678
# Assam                                          441675              422687
# Bihar                                         1778632             1259758
# Chandigarh                                      12887                1566
# Chhattisgarh                                   395756              379698
# Dadra & Nagar Haveli                             5677                2531
# Daman & Diu                                      3052                2982
# Delhi                                          242016              248648
# Goa                                             16255               15368
# ...

# %%
df['Lakshadweep','% Children given Vitamin A Dose 9 to Children given Vit A dose1'] = '-1'

# %%
df['Number of fully immunized children (9-11 months)']
# Out:
# All India               16,774,596
# A & N Islands                3,662
# Andhra Pradesh             635,164
# Arunachal Pradesh           12,484
# Assam                      435,433
# Bihar                    1,722,872
# Chandigarh                  12,769
# Chhattisgarh               383,010
# Dadra & Nagar Haveli         5,518
# Daman & Diu                  3,039
# Delhi                      221,771
# Goa                         13,833
# Gujarat                    845,547
# Haryana                    352,489
# Himachal Pradesh            83,320
# Jammu & Kashmir            140,242
# Jharkhand                  477,704
# Karnataka                  766,925
# Kerala                     351,308
# Lakshadweep                    776
# Madhya Pradesh           1,034,031
# Maharashtra              1,389,171
# Manipur                     30,983
# Meghalaya                   51,287
# Mizoram                     13,904
# Nagaland                    14,736
# Odisha                     516,601
# ...

# %%
df.loc['Lakshadweep','% Children given Vitamin A Dose 9 to Children given Vit A dose1'] = '-1'

# %%
df.drop(columns = ('Lakshadweep', '% Children given Vitamin A Dose 9 to Children given Vit A dose1'),inplace =True)

# %%
df.loc['Lakshadweep']
# Out:
# Estimated Number of Annual Live Births ##                                                                   1000
# Total Number of reported live births                                                                         511
# % Live Births to Estimated Annual Live Births                                                               51.1
# % Total Reported Live Births to Total Deliveries                                                            99.6
# Total Number of reported Still Births                                                                         12
# % live birth to Reported Birth                                                                              97.7
# Number of Newborns weighed at birth                                                                          503
# Number of Infants given OPV 0 (Birth Dose)                                                                   528
# ...

# %% [markdown]
# ## Changes for undo

# %%
df['% Children given Vitamin A Dose 9 to Children given Vit A dose1'] = df['% Children given Vitamin A Dose 9 to Children given Vit A dose1'].astype(float)

# %%
df.dtypes
# Out:
# Estimated Number of Annual Live Births ##                                                                    int64
# Total Number of reported live births                                                                         int64
# % Live Births to Estimated Annual Live Births                                                              float64
# % Total Reported Live Births to Total Deliveries                                                           float64
# Total Number of reported Still Births                                                                        int64
# % live birth to Reported Birth                                                                             float64
# Number of Newborns weighed at birth                                                                          int64
# Number of Infants given OPV 0 (Birth Dose)                                                                   int64
# ...

# %%
clean_helper('Adverse Events Following Imunisation (Others)')

# %%
l
# Out:
# Index(['Number of Infants given DPT1', 'Number of Infants given DPT2',
#        'Number of Infants given DPT3', 'Number of Infants given Pentavalent 1',
#        'Number of Infants given Pentavalent 2',
#        'Number of Infants given Pentavalent 3'],
#       dtype='object')

# %%
df.loc['Tamil Nadu',['Number of Infants given DPT1', 'Number of Infants given DPT2',
       'Number of Infants given DPT3']] = np.nan

# %%
l = ['Number of Infants given DPT1', 'Number of Infants given DPT2',
       'Number of Infants given DPT3']

# %%
for x in l:
    clean_helper(x)

# %%
df.loc['A & N Islands',l] = np.nan

# %%
df.dtypes
# Out:
# Estimated Number of Annual Live Births ##                                                                    int64
# Total Number of reported live births                                                                         int64
# % Live Births to Estimated Annual Live Births                                                              float64
# % Total Reported Live Births to Total Deliveries                                                           float64
# Total Number of reported Still Births                                                                        int64
# % live birth to Reported Birth                                                                             float64
# Number of Newborns weighed at birth                                                                          int64
# Number of Infants given OPV 0 (Birth Dose)                                                                   int64
# ...

# %% [markdown]
# # child_health_13_14.csv

# %%
df = pd.read_csv('child_health_13_14.csv')

# %% [markdown]
# df.head()

# %%
tmp = pd.DataFrame(df.dtypes)
l = tmp[tmp[0] == 'object'].index
l
# Out:
# Index([], dtype='object')

# %%
df
# Out:
#                       Estimated Number of Annual Live Births ##  \
# All India                                              26670000
# A & N Islands                                              6000
# Andhra Pradesh Old                                      1504000
# Arunachal Pradesh                                         27000
# Assam                                                    720000
# Bihar                                                   2967000
# Chandigarh                                                17000
# Chhattisgarh                                             644000
# Dadra & Nagar Haveli                                      10000
# Daman & Diu                                                5000
# Delhi                                                    310000
# Goa                                                       20000
# Gujarat                                                 1298000
# Haryana                                                  562000
# ...

# %%
df.loc['Tamil Nadu',l] = np.nan

# %%
for x in l:
    clean_helper(x)

# %%
df.loc['Lakshadweep','Total Number of Infant Deaths reported'] = np.nan

# %%
def clean_float(x):
    df[x] = df[x].apply(lambda x : x.replace(',',''))
    df[x] = df[x].astype(float)

# %%
l = ['% Deaths due to Sepsis to Total Reported Infant Deaths',
       '% Deaths due to Asphyxia to Total Reported Infant Deaths',
       '% Deaths due to LBW to Total Reported Infant Deaths',
       '% Deaths due to Pneumonia to Total Reported Infant Deaths',
       '% Deaths due to Diarrhoea to Total Reported Infant Deaths',
       '% Deaths due to Fever to Total Reported Infant Deaths',
       '% Deaths due to Measles to Total Reported Infant Deaths',
       '% Deaths due to Other Causes to Total Reported Infant Deaths']

# %%
df.loc['Lakshadweep',l] = np.nan

# %%
for x in l:
    clean_float(x)

# %%
df[l]
# Out:
#                       % Deaths due to Sepsis to Total Reported Infant Deaths  \
# All India                                                           7.3
# A & N Islands                                                      25.0
# Andhra Pradesh Old                                                  2.3
# Arunachal Pradesh                                                   3.3
# Assam                                                               4.2
# Bihar                                                               9.1
# Chandigarh                                                         40.7
# Chhattisgarh                                                        3.7
# Dadra & Nagar Haveli                                               16.8
# Daman & Diu                                                         2.5
# Delhi                                                              22.8
# Goa                                                                 0.0
# ...

# %%
#child_health_12_13.csv

# %%
df.to_csv('child_health_12_13.csv')

# %%
df.head()
# Out:
#                    Estimated Number of Annual Live Births ##  \
# All India                                         26,536,000
# A & N Islands                                          6,000
# Andhra Pradesh Old                                 1,500,000
# Arunachal Pradesh                                     27,000
# Assam                                                715,000
#
#                    Total Number of reported live births  \
# All India                                    15,842,699
# A & N Islands                                     3,815
# Andhra Pradesh Old                            1,090,431
# Arunachal Pradesh                                11,141
# Assam                                           421,932
#
#                     % Live Births to Estimated Annual Live Births  \
# All India                                                    59.7
# A & N Islands                                                63.5
# ...

# %%
tmp = pd.DataFrame(df.dtypes)
l = tmp[tmp[0] == 'object'].index
l
# Out:
# Index(['Number of Infants given Pentavalent 1',
#        'Number of Infants given Pentavalent 2',
#        'Number of Infants given Pentavalent 3',
#        'Number of Infants given Measles',
#        'Number of fully immunized children (9-11 months)',
#        'Vitamin - A dose 1', 'Adverse Events Following Imunisation (Others)',
#        'Total Number of Infant Deaths reported'],
#       dtype='object')

# %%
l = ['Number of Infants given Measles',
       'Number of fully immunized children (9-11 months)',
       'Vitamin - A dose 1', 'Adverse Events Following Imunisation (Others)',
       'Total Number of Infant Deaths reported']

# %%
for x in l:
    clean_helper(x)

# %%
df.dtypes
# Out:
# Estimated Number of Annual Live Births ##                                                                    int64
# Total Number of reported live births                                                                         int64
# % Live Births to Estimated Annual Live Births                                                              float64
# % Total Reported Live Births to Total Deliveries                                                           float64
# Total Number of reported Still Births                                                                        int64
# % live birth to Reported Birth                                                                             float64
# Number of Newborns weighed at birth                                                                          int64
# Number of Infants given OPV 0 (Birth Dose)                                                                   int64
# ...

# %% [markdown]
# #child_health_11_12.csv

# %%
df.to_csv('child_health_11_12.csv')

# %% [markdown]
# df.head()

# %%
tmp = pd.DataFrame(df.dtypes)
l = tmp[tmp[0] == 'object'].index
l
# Out:
# Index(['Number of Infants given Pentavalent 1',
#        'Number of Infants given Pentavalent 2',
#        'Number of Infants given Pentavalent 3',
#        'Number of Infants given Measles',
#        'Number of fully immunized children (9-11 months)',
#        'Vitamin - A dose 1', 'Adverse Events Following Imunisation (Others)',
#        'Total Number of Infant Deaths reported'],
#       dtype='object')

# %%
l = ['Number of Infants given Measles',
       'Number of fully immunized children (9-11 months)',
       'Vitamin - A dose 1', 'Adverse Events Following Imunisation (Others)',
       'Total Number of Infant Deaths reported']

# %%
df[l]
# Out:
#                      Number of Infants given Measles  \
# All India                                 16,566,614
# A & N Islands                                  3,811
# Andhra Pradesh Old                         1,075,599
# Arunachal Pradesh                             10,924
# Assam                                        454,855
# Bihar                                      1,752,774
# Chandigarh                                    12,144
# Chhattisgarh                                 393,864
# Dadra & Nagar Haveli                           5,148
# Daman & Diu                                    2,212
# Delhi                                        170,442
# Goa                                           15,890
# Gujarat                                      865,768
# Haryana                                      407,072
# Himachal Pradesh                              87,414
# Jammu & Kashmir                              152,309
# Jharkhand                                    516,389
# ...

# %%
df.loc['Goa',l] = np.nan

# %%
for x in l:
    clean_float(x)

# %%
for x in l:
    clean_helper(x)

# %%
df.dtypes
# Out:
# Estimated Number of Annual Live Births ##                                                                    int64
# Total Number of reported live births                                                                         int64
# % Live Births to Estimated Annual Live Births                                                              float64
# % Total Reported Live Births to Total Deliveries                                                           float64
# Total Number of reported Still Births                                                                        int64
# % live birth to Reported Birth                                                                             float64
# Number of Newborns weighed at birth                                                                          int64
# Number of Infants given OPV 0 (Birth Dose)                                                                   int64
# ...

# %% [markdown]
# # child_health_10_11.csv

# %%
df.to_csv('child_health_10_11.csv')

# %%
df
# Out:
#                      Estimated Number of Annual Live Births ##  \
# All India                                           26,980,000
# A & N Islands                                            8,000
# Andhra Pradesh Old                                   1,553,000
# Arunachal Pradesh                                       27,000
# Assam                                                  727,000
# Bihar                                                2,809,000
# Chandigarh                                              23,000
# Chhattisgarh                                           630,000
# Dadra & Nagar Haveli                                     9,000
# Daman & Diu                                              5,000
# Delhi                                                  335,000
# Goa                                                     24,000
# Gujarat                                              1,327,000
# Haryana                                                581,000
# ...

# %%
tmp = pd.DataFrame(df.dtypes)
l = tmp[tmp[0] == 'object'].index
l
# Out:
# Index(['Number of Infants given Pentavalent 1',
#        'Number of Infants given Pentavalent 2',
#        'Number of Infants given Pentavalent 3'],
#       dtype='object')

# %%
l = ['Adverse Events Following Imunisation (Others)',
       'Total Number of Infant Deaths reported']

# %%
df[l]
# Out:
#                      Adverse Events Following Imunisation (Others)  \
# All India                                                   71,067
# A & N Islands                                                   70
# Andhra Pradesh Old                                           1,237
# Arunachal Pradesh                                               19
# Assam                                                          866
# Bihar                                                          656
# Chandigarh                                                      13
# Chhattisgarh                                                 2,978
# Dadra & Nagar Haveli                                             5
# Daman & Diu                                                      3
# Delhi                                                           25
# Goa
# Gujarat                                                      4,548
# Haryana                                                     11,243
# ...

# %%
for x in l:
    clean_helper(x)

# %%
df.loc['Goa',l] = np.nan

# %%
for x in l:
    clean_float(x)

# %%
df.loc['Sikkim',['Adverse Events Following Imunisation (Others)']] = np.nan

# %% [markdown]
# # child_health_09_10.csv

# %%
df = pd.read_csv('child_health_09_10.csv')

# %%
df.head()
# Out:
#                     Estimated Number of Annual Live Births ##  \
# All India                                            26606000
# A & N Islands                                            8000
# Andhra Pradesh Old                                    1539000
# Arunachal Pradesh                                       27000
# Assam                                                  718000
#
#                     Total Number of reported live births  \
# All India                                       15366425
# A & N Islands                                       4545
# Andhra Pradesh Old                               1172573
# Arunachal Pradesh                                   7234
# Assam                                             354983
#
#                     % Live Births to Estimated Annual Live Births  \
# All India                                                    57.7
# A & N Islands                                                56.8
# ...

# %%
tmp = pd.DataFrame(df.dtypes)
l = tmp[tmp[0] == 'object'].index
l
# Out:
# Index([], dtype='object')

# %%
clean_helper('Estimated Number of Annual Live Births ##')

# %% [markdown]
# # need to be changed

# %%
df.loc['Daman & Diu',l] = np.nan

# %%
l = [       'Adverse Events Following Imunisation (Others)',
       'Total Number of Infant Deaths reported']

# %%
def clean_space1(x):
    df[x] = df[x].apply(lambda x: np.nan if x== -1 else x)
def clean_space2(x):
    df[x] = df[x].apply(lambda x: x.replace(' ','-1'))

# %%
df[l]
# Out:
#                      Number of Infants given Pentavalent 1  \
# All India
# A & N Islands
# Andhra Pradesh Old
# Arunachal Pradesh
# Assam
# Bihar
# Chandigarh
# Chhattisgarh
# Dadra & Nagar Haveli
# Daman & Diu                                             -1
# Delhi
# Goa
# Gujarat
# Haryana
# Himachal Pradesh
# Jammu & Kashmir
# Jharkhand
# Karnataka
# Kerala
# Lakshadweep
# Madhya Pradesh
# Maharashtra
# Manipur
# Meghalaya
# Mizoram
# Nagaland
# Odisha
# Puducherry
# Punjab
# Rajasthan
# Sikkim
# Tamil Nadu
# Tripura
# Uttar Pradesh
# Uttarakhand
# West Bengal
#
#                      Number of Infants given Pentavalent 2  \
# All India
# A & N Islands
# Andhra Pradesh Old
# Arunachal Pradesh
# Assam
# Bihar
# Chandigarh
# Chhattisgarh
# Dadra & Nagar Haveli
# Daman & Diu                                             -1
# Delhi
# Goa
# Gujarat
# Haryana
# Himachal Pradesh
# Jammu & Kashmir
# Jharkhand
# Karnataka
# Kerala
# Lakshadweep
# Madhya Pradesh
# Maharashtra
# Manipur
# ...

# %%
for x in l:
    clean_space1(x)

# %%
df[l]
# Out:
#                       Number of Infants given Pentavalent 1  \
# All India                                               NaN
# A & N Islands                                           NaN
# Andhra Pradesh Old                                      NaN
# Arunachal Pradesh                                       NaN
# Assam                                                   NaN
# Bihar                                                   NaN
# Chandigarh                                              NaN
# Chhattisgarh                                            NaN
# Dadra & Nagar Haveli                                    NaN
# Daman & Diu                                             NaN
# Delhi                                                   NaN
# Goa                                                     NaN
# Gujarat                                                 NaN
# Haryana                                                 NaN
# Himachal Pradesh                                        NaN
# ...

# %% [markdown]
# # child_health_08_09.csv

# %%
df.to_csv('child_health_08_09.csv')

# %%
df
# Out:
#                      Estimated Number of Annual Live Births ##  \
# All India                                           26,565,000
# A & N Islands                                            7,000
# Andhra Pradesh Old                                   1,549,000
# Arunachal Pradesh                                       27,000
# Assam                                                  721,000
# Bihar                                                2,778,000
# Chandigarh                                              20,000
# Chhattisgarh                                           622,000
# Dadra & Nagar Haveli                                     9,000
# Daman & Diu                                              4,000
# Delhi                                                  312,000
# Goa                                                     24,000
# Gujarat                                              1,314,000
# Haryana                                                572,000
# ...

# %%
tmp = pd.DataFrame(df.dtypes)
l = tmp[tmp[0] == 'object'].index
l
# Out:
# Index(['Adverse Events Following Imunisation (Others)'], dtype='object')

# %%
l = ['% Live Births to Estimated Annual Live Births',
       '% Total Reported Live Births to Total Deliveries',
       '% live birth to Reported Birth', 'Number of Newborns weighed at birth',
       '% Newborns given OPV0 at birth to Reported live birth',
       '% Newborns given BCG to Reported live birth']

# %%
df[l]
# Out:
#                      Adverse Events Following Imunisation (Others)
# All India                                                   35,759
# A & N Islands
# Andhra Pradesh Old                                             163
# Arunachal Pradesh                                               18
# Assam                                                        2,508
# Bihar                                                        1,735
# Chandigarh
# Chhattisgarh                                                   692
# Dadra & Nagar Haveli
# Daman & Diu
# Delhi                                                          189
# Goa
# Gujarat                                                      7,563
# Haryana                                                        959
# Himachal Pradesh
# Jammu & Kashmir                                              1,310
# Jharkhand
# Karnataka                                                    3,812
# Kerala                                                           1
# ...

# %%
def clean_space1(x):
    df[x] = df[x].apply(lambda x: np.nan if x== -999.0 else x)
def clean_space2(x):
    df[x] = df[x].apply(lambda x: x.replace(' ','-999'))

# %%
for x in l:
    clean_space2(x)

# %%
for x in l:
    clean_helper(x)

# %%
for x in l:
    clean_space1(x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, All India to West Bengal
# Data columns (total 44 columns):
# Estimated Number of Annual Live Births ##                                                                  36 non-null int64
# Total Number of reported live births                                                                       36 non-null int64
# % Live Births to Estimated Annual Live Births                                                              36 non-null float64
# % Total Reported Live Births to Total Deliveries                                                           36 non-null float64
# Total Number of reported Still Births                                                                      36 non-null int64
# % live birth to Reported Birth                                                                             36 non-null float64
# ...

# %%
df[l]
# Out:
#                       Number of Infants given Pentavalent 1  \
# All India                                          346727.0
# A & N Islands                                           NaN
# Andhra Pradesh Old                                      0.0
# Arunachal Pradesh                                       0.0
# Assam                                                   0.0
# Bihar                                                   NaN
# Chandigarh                                              NaN
# Chhattisgarh                                            0.0
# Dadra & Nagar Haveli                                    NaN
# Daman & Diu                                             NaN
# Delhi                                                   NaN
# Goa                                                     0.0
# Gujarat                                               856.0
# Haryana                                                10.0
# Himachal Pradesh                                        NaN
# ...

# %%
df.to_csv('child_health_12_13.csv')

# %%
l = ['Number of Infants given Pentavalent 1',
       'Number of Infants given Pentavalent 2',
       'Number of Infants given Pentavalent 3']

# %%
df[l]
# Out:
#                      Number of Infants given Pentavalent 1  \
# All India                                          346,727
# A & N Islands
# Andhra Pradesh Old                                       0
# Arunachal Pradesh                                        0
# Assam                                                    0
# Bihar
# Chandigarh
# Chhattisgarh                                             0
# Dadra & Nagar Haveli
# Daman & Diu
# Delhi
# Goa                                                      0
# Gujarat                                                856
# Haryana                                                 10
# Himachal Pradesh
# Jammu & Kashmir
# Jharkhand                                                0
# Karnataka                                                3
# Kerala
# Lakshadweep
# Madhya Pradesh                                           3
# Maharashtra
# Manipur
# Meghalaya
# Mizoram
# Nagaland
# Odisha                                                   0
# ...

# %%
df = pd
